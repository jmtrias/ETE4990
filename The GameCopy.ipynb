# %%
import json
"""This is my json file that stores all of my pallballs"""
Palballs = [{
    "Name": "Regular Ball", 
    "Slogan": "'Just a regular Palball'",
    "Effectiveness": {"Catch Percentage": 30},
  
},
{  
    "Name": "Great Ball",
    "Slogan": "'Better... but not perfect'",
    "Effectiveness": {"Catch Percentage": 55}


},
{  
    "Name": "Master Ball",
    "Slogan": "'Literally one shot'",
    "Effectiveness": {"Catch Percentage": 100}


},
{
    "Name": "Fast Ball",
    "Slogan": "'Wanna see it again?'",
    "Effectiveness": {"Catch Percentage": 40}
},#original ones end
{  
    "Name": "SLow Ball",
    "Slogan": "'You thought I was fast? Think again'",
    "Effectiveness": {"Catch Percentage": 10}


},
{  
    "Name": "Grass Ball",
    "Slogan": "'The greener the grass, the more chance you'll be catched'",
    "Effectiveness": {"INNAFFECTIVE against fire and water types. Grass catch": 72}


},
{
    "Name": "Fire Ball",
    "Slogan": "'You are NOT too hot to handle, especially fire types'",
    "Effectiveness": {"INNAFFECTIVE against grass and water types. Fire catch": 75}
},#8
{  
    "Name": "Water Ball",
    "Slogan": "'Wet like water, except this ball is water tight'",
    "Effectiveness": {"INNAFFECTIVE against fire and grass types. Water catch": 73}


},
{  
    "Name": "Foot Ball",
    "Slogan": "'GO LONG, the taller the Palmon the greater the catch'",
    "Effectiveness": {"Catch Percentage": 50}


},
{
    "Name": "Golf Ball",
    "Slogan": "'Catch in one? The smaller the Palmon the greater the catch'",
    "Effectiveness": {"Catch Percentage": 25}
},
{  
    "Name": "Not so Great Ball",
    "Slogan": "'Are you trolling at this point...'",
    "Effectiveness": {"Catch Percentage": 1}


},#12
{  
    "Name": "Master Ball",
    "Slogan": "'Literally one shot'",
    "Effectiveness": {"Catch Percentage": 100}


},
{
    "Name": "Basket Ball",
    "Slogan": "'SWOOSHH if you can shoot a 3 you can catch ME'",
    "Effectiveness": {"Catch Percentage": 30}
},
{  
    "Name": " LeBall",
    "Slogan": "'Young enough to play'",
    "Effectiveness": {"Catch Percentage": 23}


},
{  
    "Name": "Tennis Ball",
    "Slogan": "'Serena would be proud, DUCE'",
    "Effectiveness": {"Catch Percentage": 20}


},#16
{
    "Name": "KOBE Ball",
    "Slogan": "'I don't pass, only shoot'",
    "Effectiveness": {"Catch Percentage": 100}
},
{  
    "Name": "Ball",
    "Slogan": "'This is what happens when it's 3am and you're still tryna code'",
    "Effectiveness": {"Catch Percentage": 1}


},
{  
    "Name": "Gomu Gomu Ball",
    "Slogan": "'One piece of pure rubber'",
    "Effectiveness": {"Catch Percentage": 99}


},
{
    "Name": "Dragon Ball",
    "Slogan": "'I heard if you get all seven then it's 100% effective...wrong game'",
    "Effectiveness": {"Catch Percentage": 14}
},#20
{  
    "Name": "Poke Ball",
    "Slogan": "'This is DEFINITELY plagiarising'",
    "Effectiveness": {"Catch Percentage": 69}


},
{  
    "Name": "Pal Ball",
    "Slogan": "'Ash never could Kethchum'",
    "Effectiveness": {"Catch Percentage": 77}


},
{
    "Name": "Sharingan Ball",
    "Slogan": "'You're already caught before you moved'",
    "Effectiveness": {"Catch Percentage": 100}
},
{  
    "Name": "Rasen-Ball",
    "Slogan": "'A bright blue ball emitting mounds of chakra'",
    "Effectiveness": {"Catch Percentage": 80}


},#24
{  
    "Name": "Onigiri Ball",
    "Slogan": "'Lures Palmon in with it's savory taste'",
    "Effectiveness": {"Catch Percentage": 65}


},
{
    "Name": "Pool Ball",
    "Slogan": "'You need to wait for the queue before you break this ball'",
    "Effectiveness": {"Catch Percentage": 63}
},
{  
    "Name": "Medicine Ball",
    "Slogan": "'I'd rather stay sick than get hit with one of these'",
    "Effectiveness": {"Catch Percentage": 78}


},
{  
    "Name": "Dodge Ball",
    "Slogan": "'Either catch or duck, one touch and you're caught'",
    "Effectiveness": {"Catch Percentage": 85}


},#28
{
    "Name": "Base Ball",
    "Slogan": "'If you hit this out of the park then you can escape, otherwise you're out'",
    "Effectiveness": {"Catch Percentage": 45}
},
{  
    "Name": "Paint Ball",
    "Slogan": "'This might hurt, but at least you'll look pretty'",
    "Effectiveness": {"Catch Percentage": 33}


},
{  
    "Name": "Curve Ball",
    "Slogan": "'Just like your love life, get curved'",
    "Effectiveness": {"Catch Percentage": 20}

},#########30-50
{
    "Name": "Round Ball",
    "Slogan": "'The roundest of Palballs, so round it's the new calibration for round'",
    "Effectiveness": {"Catch Percentage": 33}
},
{  
    "Name": "Square Ball",
    "Slogan": "'There's no such thing, but all Palmon fear this for some reason'",
    "Effectiveness": {"Catch Percentage": 85}


},
{  
    "Name": "Kawaii Ball",
    "Slogan": "'So cute that it lures Palmon in with its Kawaii-ness...'",
    "Effectiveness": {"Catch Percentage": 100}


},
{
    "Name": "Val Ball",
    "Slogan": "'You thought LoL was toxic, this hit another threshold'",
    "Effectiveness": {"Catch Percentage": 60}
},
{  
    "Name": "Tiger Woods Ball",
    "Slogan": "'Just when you thought it retired, it hit a hole in one'",
    "Effectiveness": {"Catch Percentage": 78}


},
{  
    "Name": "Michael Phelps Ball",
    "Slogan": "'Water types thought they were fast'",
    "Effectiveness": {"Catch Percentage": 90}


},
{
    "Name": "Disco Ball",
    "Slogan": "'So shiny. So sparkly. Gonna have to hit the dougie to this one'",
    "Effectiveness": {"Catch Percentage": 88}
},
{  
    "Name": "Ball2",
    "Slogan": "'This is what happens when it's 4am and you're still tryna code'",
    "Effectiveness": {"Catch Percentage": 1}


},
{  
    "Name": "Quick Ball",
    "Slogan": "'It's like the fast ball, but quicker...smh'",
    "Effectiveness": {"Catch Percentage": 99}


},
{
    "Name": "Dragon Ball Z",
    "Slogan": "'This is when you run out of ideas but you still need content'",
    "Effectiveness": {"Catch Percentage": 95}
},
{  
    "Name": "Apple Ball",
    "Slogan": "'WHen you want to launch something different but use other company's tech'",
    "Effectiveness": {"Catch Percentage": 55}


},
{  
    "Name": "Paddle-Ball",
    "Slogan": "'This is really a sport'",
    "Effectiveness": {"Catch Percentage": 77}


},
{
    "Name": "Corn Ball",
    "Slogan": "'The premise of this game'",
    "Effectiveness": {"Catch Percentage": 100}
},
{  
    "Name": "Pin-Ball",
    "Slogan": "'A small silver ball that will bounce around till you rage and give up'",
    "Effectiveness": {"Catch Percentage": 99}


},
{  
    "Name": "Love Ball",
    "Slogan": "'Lures Palmon in with love and affection'",
    "Effectiveness": {"Catch Percentage": 65}


},
{
    "Name": "Volley Ball",
    "Slogan": "'A high ball that will strike opponents with a might force'",
    "Effectiveness": {"Catch Percentage": 63}
},
{  
    "Name": "Medicine Ball",
    "Slogan": "'I'd rather stay sick than get hit with one of these'",
    "Effectiveness": {"Catch Percentage": 78}


},
{  
    "Name": "Em-Ball",
    "Slogan": "'Kinda eerie.. '",
    "Effectiveness": {"Catch Percentage": 85}


},
{
    "Name": "Lamelo Ball",
    "Slogan": "'Hornets and flying type beware'",
    "Effectiveness": {"Catch Percentage": 73}
},
{  
    "Name": "Snow Ball",
    "Slogan": "'A fire type's worst nightmare; freezes its opponents'",
    "Effectiveness": {"Catch Percentage": 86}


},
{  
    "Name": "Goof Ball",
    "Slogan": "'Just when you thought Corn Ball was bad. Makes you laugh until you can't move'",
    "Effectiveness": {"Catch Percentage": 20}

}
]
Palfile = 'Palballs.json'
with open(Palfile, 'w') as f:
    json.dump(Palballs, f)

# %%
import json
""" This will save the player's team name and name data """
def load_player():
    """Loads the player data from the saved file."""
  
    
    try:
        with open("player_data.json", "r") as file:
            player_data = json.load(file)
        player_name = player_data.get('name')
        player_team = player_data.get('team')
        if player_name and player_team:  # Check if both name and team are loaded
            return player_name, player_team  # Return player name and team as a tuple
        else:
            return None, None  # Return None if player data is incomplete
    except FileNotFoundError:
        return None, None  # Return None if file not found


def save_player(player):
    """Saves the current state of the player's game."""
    player_data = {
        'name': player.name,
        'team': player.team
    }
    with open("player_data.json", "w") as file:
        json.dump(player_data, file, indent=4)
    print("Game saved successfully!")

# %%
import json

def load_inventory():
    """Loads the player's inventory from a saved file."""
    try:
        with open("player_inventory.json", "r") as file:
            inventory_data = json.load(file)
        return inventory_data
    except FileNotFoundError:
        print("No saved inventory found.")
        return []


def save_inventory(inventory):
    """ This will save my player's inventory"""
    filepath = 'player_inventory.json'
    with open(filepath, 'w') as file:
        json.dump(inventory, file, indent=4)
    print("Inventory saved successfully.")

    print("Your final Palballs:")
    for item in player.inventory:
        print(item["Name"])

# %%
import json

Palfile = 'Palballs.json' 
with open(Palfile) as f:
    Palballs = json.load(f)

print("Welcome to the world of Palmon!")
            
class Player:
    """ sets the condition of a player's team and name """
    def __init__(self, name, team=None):
    
        if player_team == "Gold":
            print("Welcome to team Gold!")
        else:
            print("Welcome to team Silver!")
        self.name = name
        self.team = team
        self.inventory = []
        self.display_inventory = []
        
    def add_palball(self, palball):
        self.inventory.append(palball)
        print(f"Added {palball['Name']} to inventory.")
        
    def remove_palball(self, palball_name):
        for item in self.inventory:
            if item["Name"] == palball_name:
                self.inventory.remove(item)
                print(f"Removed {palball_name} from inventory.")

    def to_dict(self):
        """Converts the instance into a dictionary."""
        return {
            'name': self.name,
            'team': self.team
        }


class Palmon:
        """ sets Palmon's statistics """
        def __init__ (self, name, palmon_type, health, damage, accuracy, critical_hit):
            self.name = name
            self.palmon_type = palmon_type
            self.damage = damage
            self.accuracy = accuracy
            self.critical_hit = critical_hit
            self.health = health
        
        def start_health(self):
            print("Starting health:", self.health) 
            
        def start_damage(self):
            print("Starting damage:", self.damage)
            
        def start_accuracy(self):
            print(palmon_name,"'s accuracy is", self.accuracy)
            
        def start_critical(self):    
            print(palmon_name,"'s critical hit is", self.critical_hit)
            
            
class Charmander(Palmon):
    """Palmon charmander, inheritting from palmon class"""
    def __init__(self, palmon_type, health, damage, accuracy, critical_hit, special):
        """stating what will be inheritted from Palmon parent"""
        super().__init__(self, palmon_type, health, damage, accuracy, critical_hit)
        self.special = special
        
    def dragon_breath(self):
        """Special move: Dragon Breath. If executed, this attack has 3x damage but 40% accuracy"""
        print("Special move: Dragon Breath. If executed, this attack has 3x damage and 40% accuracy")
        self.damage *=3
        self.accuracy = "40%"
        
    def to_dict(self):
        """Converts Charmander object to a dictionary"""
        return {
            "name": self.name,
            "type": self.palmon_type,
            "health": self.health,
            "damage": self.damage,
            "accuracy": self.accuracy,
            "critical_hit": self.critical_hit,
            "special": self.special
        }

class Squirtle(Palmon):
    """Palmon Squirtle, inheritting from palmon class"""
    def __init__(self, palmon_type, health, damage, accuracy, critical_hit, special):
        """stating what will be inheritted from Palmon parent"""
        super().__init__(self,palmon_type, health, damage, accuracy, critical_hit)
        self.special = special
        
    def aqua_jet(self):
        """Special move: Aqua Jet. If executed, this attack has 2x damage but 50% accuracy"""
        print("Special move: Aqua Jet. If executed, this attack has 2x damage and 50% accuracy")
        self.damage *=2
        self.accuracy = "50%"

    def to_dict(self):
        """Converts Squirtle object to a dictionary"""
        return {
            "name": self.name,
            "type": self.palmon_type,
            "health": self.health,
            "damage": self.damage,
            "accuracy": self.accuracy,
            "critical_hit": self.critical_hit,
            "special": self.special
        }
# Out:
# Welcome to the world of Palmon!

# %%
"""This will either load previous player or ask player to create new character"""
load_choice = input("Do you want to load a saved game? (yes/no): ").lower()
player_name, player_team = load_player()
if load_choice == "yes":    
    if player_name and player_team:  # Check if player data is loaded
        print(f"Welcome back {player_name} from team {player_team}!")
    else:
        print("No saved player found, starting a new game.")
elif load_choice == "no":
    player_name = input("What is your name?") # if no data loaded then it will ask to create a character
    player_team = input("What team do you want to join? 'Gold' or 'Silver'")
    while player_team not in ("Gold", "Silver"):
        print("Invalid, choose a team")
        player_team = input("What team do you want to join? 'Gold' or 'Silver'")
    player = Player(player_name, player_team)
# Out:
# Do you want to load a saved game? (yes/no):  yes
# Welcome back Jeremy from team Gold!

# %%
""" This will LOAD the saved inventory """
load_choice = input("Do you want to load your inventory? (yes/no): ").lower()
if load_choice == "yes":
    player_inventory = load_inventory()
else:
    player_inventory = []
    
if player_inventory:
    print("Your Palballs:")
    for item in player_inventory:
        print(item["Name"])
else:
    print("Start from scratch")
# Out:
# Do you want to load your inventory? (yes/no):  yes
# Your Palballs:
# Great Ball
# Great Ball
# Sharingan Ball

# %%
"""This saves the game of the player, it's a checkpoint"""
while True:
    checkpoint = input("Do you want to save the game? (yes/no): ").lower()
    if checkpoint == "yes":
        save_player(player)
        break
    """ This will provide an option to quit the game or continue"""
    quit_choice = input("Do you want to quit the game? (yes/no): ").lower()
    if quit_choice == "yes":
        save_player(player)
        print("Game saved. See you next time!")
        break
# Out:
# Do you want to save the game? (yes/no):  yes
# Game saved successfully!

# %%
"""This section of code is to choose your palmon """
my_palmon = input("Choose your Palmon! 'Charmander' or 'Squirtle'")
while my_palmon not in ("Charmander", "Squirtle"): #If user input is not either "Charmander" or "Squirtle" it = invalid response
    print("Invalid, choose a Palmon")
    my_palmon = input("Choose your Palmon! 'Charmander' or 'Squirtle'")
if my_palmon == "Charmander":  #if charmander you get his attributes
    palmon_name = "Charmander"
    my_palmon = Charmander("Fire", 100, 10, "80%", "+10", "Dragon Breath")
    print("Your Palmon's name is:", palmon_name)
    my_palmon.start_health()
    my_palmon.start_damage()
    my_palmon.start_accuracy()
    my_palmon.start_critical()
    my_palmon.dragon_breath()
elif my_palmon == "Squirtle": #if squirtle you get his attributes
    palmon_name = "Squirtle"
    my_palmon = Squirtle("Water", 100, 10, "80%", "+10", "Aqua Jet")
    print("Your Palmon's name is:", palmon_name)
    my_palmon.start_health()
    my_palmon.start_damage()
    my_palmon.start_accuracy()
    my_palmon.start_critical()
    my_palmon.aqua_jet()
# Out:
# Choose your Palmon! 'Charmander' or 'Squirtle' Charmander
# Your Palmon's name is: Charmander
# Starting health: 100
# Starting damage: 10
# Charmander 's accuracy is 80%
# Charmander 's critical hit is +10
# Special move: Dragon Breath. If executed, this attack has 3x damage and 40% accuracy

# %%
print("Now time to equip Palballs!!")
action = input("Would you like to 'add'/'remove' a Palball or 'exit' or 'view inventory'? ").lower()
while action != "exit":
    if action == "add":
        print("Available Palballs:")
        for i, palball in enumerate(Palballs, 1):
            print(f"{i}. {palball['Name']}: {palball['Slogan']}\n\t{palball['Effectiveness']}\n")
         #   print(f"{i}.\n\t{palball['Effectiveness']}")
        try:
            choice = int(input("Enter the number of the Palball to add: ")) - 1
            if 0 <= choice < len(Palballs):
                player.add_palball(Palballs[choice])
            else:
                print("Invalid selection.")
        except ValueError:
            print("Please enter a valid number.")
    elif action == "remove":
        if not player.inventory:
            print("Your inventory is empty.")
        else:
            print("Your inventory:")
        for i, item in enumerate(player.inventory, 1):
            print(f"{i}. {item['Name']}")
        
        try:
            choice = int(input("Enter the number of the Palball to remove: ")) - 1
            if 0 <= choice < len(player.inventory):
                removed_item = player.inventory.pop(choice)
                print(f"Removed {removed_item['Name']} from inventory.")
            else:
                print("Invalid selection.")
        except ValueError:
            print("Please enter a valid number.")
                    
    elif action == "view inventory":
        if not player.inventory:
            print("Your inventory is empty.")
        else:    
            print("Your Palballs:")
            for item in player.inventory:
                print(item["Name"])

    
    
    else:
        print("Invalid action.")
    action = input("Would you like to 'add'/'remove' a Palball or 'exit' or 'view inventory'?? ").lower()

print("You have exited your inventory")
# Out:
# Now time to equip Palballs!!
# Would you like to 'add'/'remove' a Palball or 'exit' or 'view inventory'?  add
# Available Palballs:
# 1. Regular Ball: 'Just a regular Palball'
# 	{'Catch Percentage': 30}
#
# 2. Great Ball: 'Better... but not perfect'
# 	{'Catch Percentage': 55}
#
# 3. Master Ball: 'Literally one shot'
# 	{'Catch Percentage': 100}
#
# 4. Fast Ball: 'Wanna see it again?'
# 	{'Catch Percentage': 40}
#
# 5. SLow Ball: 'You thought I was fast? Think again'
# 	{'Catch Percentage': 10}
#
# 6. Grass Ball: 'The greener the grass, the more chance you'll be catched'
# 	{'INNAFFECTIVE against fire and water types. Grass catch': 72}
#
# 7. Fire Ball: 'You are NOT too hot to handle, especially fire types'
# 	{'INNAFFECTIVE against grass and water types. Fire catch': 75}
#
# 8. Water Ball: 'Wet like water, except this ball is water tight'
# 	{'INNAFFECTIVE against fire and grass types. Water catch': 73}
#
# 9. Foot Ball: 'GO LONG, the taller the Palmon the greater the catch'
# ...

# %%
print("Your final Palballs:")
"""This will show the final results of your inventory """
if not player.inventory:
    print("Your inventory is empty.")
else: 
    for item in player.inventory:
        print(item["Name"])
# Out:
# Your final Palballs:
# Great Ball
# Great Ball
# Sharingan Ball

# %%
"""This saves the inventory of the player, it's a checkpoint"""
while True:
    checkpoint = input("Do you want to save the game? (yes/no): ").lower()
    if checkpoint == "yes":
        save_inventory(player.inventory)
    
    quit_choice = input("Do you want to quit the game? (yes/no): ").lower()
    if quit_choice == "yes":
        save_inventory(player.inventory)
        print("Game saved. See you next time!")
        break
# Out:
# Do you want to save the game? (yes/no):  yes
# Inventory saved successfully.
# Your final Palballs:
# Great Ball
# Great Ball
# Sharingan Ball
# Do you want to quit the game? (yes/no):  yes
# Inventory saved successfully.
# Your final Palballs:
# Great Ball
# Great Ball
# Sharingan Ball
# Game saved. See you next time!
